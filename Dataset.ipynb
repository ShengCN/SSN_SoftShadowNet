# %%
# dynamic import
# %load_ext autoreload
# %autoreload 2


from torchvision import utils
import matplotlib.pyplot as plt
def show(img, title=''):
    print(img.shape, img.min(), img.max())
    plt.figure(figsize=(15,10))
    plt.imshow(img)
    plt.title(title)
    plt.show()

def show_tensor(tensor,title=''):
    img = utils.make_grid(tensor).detach().cpu().numpy().transpose(1,2,0)
    show(img, title=title)

# %%
from SSN_Dataset import SSN_Dataset
# Out:
# WARNING:param.ParameterizedMetaclass: Use method 'params' via param namespace

# %%
opt = {'hdf5_file': 'data/src/base/all_base.hdf5', 'use_ao': False}

ds = SSN_Dataset(opt, True)

for i, d in enumerate(ds):
    x = d['x']
    y = d['y']
    ibl = d['ibl']

    show(x.numpy().transpose((1,2,0)))
    show(y.numpy().transpose((1,2,0)))
    show(ibl.numpy().transpose((1,2,0)))
# Out:
# WARNING:param.Composite: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# training: 1, validation: 0
# (512, 512, 1) 0.0 1.0
# (512, 512, 1) 0.0 29.460688
# (16, 32, 1) 9.8376944e-08 0.20474999

# %%
opt = {'hdf5_file': 'data/src/base/all_base.hdf5', 'use_ao': True}

ds = SSN_Dataset(opt, True)

for i, d in enumerate(ds):
    x = d['x']
    y = d['y']
    ibl = d['ibl']

    mask = x[0:1]
    ao = x[1:]
    
    show(mask.numpy().transpose((1,2,0)))
    show(ao.numpy().transpose((1,2,0)))
    show(y.numpy().transpose((1,2,0)))
    show(ibl.numpy().transpose((1,2,0)))
# Out:
# WARNING:param.Composite: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# training: 1, validation: 0
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# WARNING:param.Gaussian: Use method 'debug' via param namespace
# (512, 512, 1) 0.0 1.0
# (512, 512, 1) 0.0 1.0
# (512, 512, 1) 0.0 28.76264
# (16, 32, 1) 3.3071714e-09 0.35331714
