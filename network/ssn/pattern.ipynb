# %%
# %load_ext autoreload
# %autoreload 2

# %%
from random_pattern import random_pattern
import matplotlib.pyplot as plt

# %%
pattern = random_pattern()
pt = pattern.get_pattern()

# %%
plt.figure()
plt.imshow(pt)
plt.show()
